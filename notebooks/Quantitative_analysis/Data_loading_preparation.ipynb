# %%
import os
import sys
import pickle

current_directory = os.getcwd()

parrent_directory = os.path.dirname(current_directory)

parrent_directory2 = os.path.dirname(parrent_directory)
sys.path.insert(0, parrent_directory2)

scripts_dir = os.path.join(parrent_directory2, 'scripts')

from scripts.main import DataPreprocessing, FinancialAnalyzer

# Check if the file exists in the 'financial-solutions-forecasting' directory
file_path = os.path.join(parrent_directory2, 'filtered_data_frames.pkl')

# Load the filtered data frames
with open(file_path, 'rb') as f:
    filtered_data_frames = pickle.load(f)

# Now you can use filtered_data_frames in your other code
#for label, df in filtered_data_frames.items():
#    print(f"{label} Data:")
#    print(df.tail())

# %%
# Iterate over each DataFrame in the dictionary and check for missing values
for label, filtered_df in filtered_data_frames.items():
    print(f"Checking missing values for {label} Data:")
    analyzer = FinancialAnalyzer(filtered_df, '2013-01-01', '2023-12-29')
    missing_values = analyzer.check_missing_values(filtered_df)
    print(missing_values)
    analyzer.check_data_type(filtered_df)
# Out:
# Checking missing values for AAPL Data:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Checking missing values for AMZN Data:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Checking missing values for GOOG Data:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Checking missing values for META Data:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Checking missing values for MSFT Data:
# ...

# %%
# Iterate over each DataFrame in the dictionary and check for missing values
for label, filtered_df in filtered_data_frames.items():
    print(f"Checking data type for {label} Data:")
    analyzer = FinancialAnalyzer(filtered_df, '2013-01-01', '2023-12-29')
    data_type = analyzer.check_data_type(filtered_df)
    print(data_type)
# Out:
# Checking data type for AAPL Data:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# dtype: object
# Checking data type for AMZN Data:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# dtype: object
# Checking data type for GOOG Data:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# Dividends              float64
# ...

# %%
# Iterate over each DataFrame in the dictionary and check for missing values
for label, filtered_df in filtered_data_frames.items():
    print(f"Description for {label}:")
    # Exclude the date column and describe the numeric columns
    numeric_df = filtered_df.select_dtypes(include=['number'])
    display(numeric_df.describe())
# Out:
# Description for AAPL:
#               Open         High          Low        Close    Adj Close  \
# count  2768.000000  2768.000000  2768.000000  2768.000000  2768.000000
# mean     72.306914    73.092193    71.567077    72.363529    70.133302
# std      56.353981    56.992647    55.763624    56.411026    56.680515
# min      13.856071    14.271429    13.753571    13.947500    11.952173
# 25%      27.574999    27.933750    27.295626    27.588126    25.088475
# 50%      43.835001    44.312500    43.623751    43.958752    41.759007
# 75%     128.952499   130.627506   127.415003   129.612499   127.174225
# max     198.020004   199.619995   197.000000   198.110001   197.361084
#
#              Volume    Dividends  Stock Splits
# count  2.768000e+03  2768.000000   2768.000000
# mean   1.612260e+08     0.002731      0.003974
# std    1.236387e+08     0.022224      0.153217
# min    2.404830e+07     0.000000      0.000000
# 25%    8.424670e+07     0.000000      0.000000
# ...
